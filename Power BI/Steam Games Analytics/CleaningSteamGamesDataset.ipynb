# %%
# Importing libaries
import pandas as pd

# %%
# Reading the data
df = pd.read_csv('D:\Data Analyst Stuff/games.csv')
df
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
# ...                                        ...           ...          ...
# 3249570                       Sotsugyo Omedeto   Mar 1, 2026        0 - 0
# 2218150                        Island on cloud  Feb 24, 2026        0 - 0
# 3788650                           Rosie Planet   Mar 1, 2026        0 - 0
# 3509140             Fear Effect 2: Retro Helix  Feb 27, 2026        0 - 0
# 4247310                      Project Liminal 2   Mar 2, 2026        0 - 0
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# ...

# %%
# Correcting headers
correct_headers = [
    'AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
    'Required age', 'Price', 'Discount', 'DLC count', 'About the game',
    'Supported languages', 'Full audio languages', 'Reviews',
    'Header image', 'Website', 'Support url', 'Support email', 'Windows',
    'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
    'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
    'Notes', 'Average playtime forever', 'Average playtime two weeks',
    'Median playtime forever', 'Median playtime two weeks', 'Developers',
    'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies'
]

# %%
# Reading the CSV again, skipping the broken first row (header=0) and supplying correct_headers this time.
df = pd.read_csv('D:\Data Analyst Stuff/games.csv', names=correct_headers, header=0)
df
# Out:
#           AppID                                   Name  Release date  \
# 0       2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1        496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2       1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3       3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4       3631080                          Maze Quest VR  Apr 24, 2025
# ...         ...                                    ...           ...
# 125850  3249570                       Sotsugyo Omedeto   Mar 1, 2026
# 125851  2218150                        Island on cloud  Feb 24, 2026
# 125852  3788650                           Rosie Planet   Mar 1, 2026
# 125853  3509140             Fear Effect 2: Retro Helix  Feb 27, 2026
# 125854  4247310                      Project Liminal 2   Mar 2, 2026
#
#        Estimated owners  Peak CCU  Required age  Price  Discount  DLC count  \
# ...

# %%
# List of heavy text/URL columns to drop
cols_to_drop = [
    'About the game', 'Supported languages', 'Full audio languages', 
    'Reviews', 'Header image', 'Website', 'Support url', 'Support email', 
    'Notes', 'Metacritic url', 'Screenshots', 'Movies'
]

# %%
df_clean = df.drop(columns=cols_to_drop)

# %%
# Exporting CSV
df_clean.to_csv('steam_games_perfected.csv', index=False)
